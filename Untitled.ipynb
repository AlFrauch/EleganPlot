# %%
import EleganPlot as elegan
import numpy as np



# Использование функций из пакета
fig, ax = elegan.create_figure_and_axes(theme='frauch', dpi=200)
# fig.set_facecolor('#2a2d31')
ax = elegan.plot([0, 1, 2, 3], [0, 1, 4, 1], ax=ax, gradient=True)
ax = elegan.plot([0, 1, 2, 3], [1, 2, 3, 3], ax=ax, gradient=True, gradient_fill_min=True)
# ax = elegan.plot([0, 1, 2, 3], [3, 1, 1,0], ax=ax, gradient=True)
ax.set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
ax.get_xlim()[0]
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Создаем данные для графиков
x = np.linspace(0, 10, 100)

# Создаем фигуру и ось
fig, ax = plt.subplots()

# Строим первый график
y1 = np.sin(x)
ax.plot(x, y1, label='sin(x)')
print(f'График номер: {len(ax.lines)}')

# Строим второй график
y2 = np.cos(x)
ax.plot(x, y2, label='cos(x)')
print(f'График номер: {len(ax.lines)}')

# Строим третий график
y3 = np.tan(x)
ax.plot(x, y3, label='tan(x)')
print(f'График номер: {len(ax.lines)}')

# Добавляем легенду и показываем график
ax.legend()
plt.show()
# Out:
# График номер: 1
# График номер: 2
# График номер: 3
